# %% [markdown]
# AMPABO RANSFORD KWAME
# 10984758
# MTEN

# %%
import pandas as pd

# %%
import matplotlib as mpl

# %%
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data=data.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity','citric acid':'citric_acid','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %% [markdown]
# MEAN VALUES FOR THE VARIOUS COLUMNS

# %%
mn_fa=data.fixed_acidity.mean()
mn_va=data.volatile_acidity.mean()
mn_ca=data.citric_acid.mean()
mn_ra=data.residual_sugar.mean()
mn_chl=data.chlorides.mean()
mn_fsd=data.free_sulfur_dioxide.mean()
mn_tsd=data.total_sulfur_dioxide.mean()
mn_dens=data.density.mean()
mn_pH=data.pH.mean()
mn_sul=data.sulphates.mean()
mn_alc=data.alcohol.mean()
mn_qua=data.quality.mean()

print('MEAN FOR THE VARIOUS COLUMNS')
print(f'fixed_acidity : {mn_fa}')
print(f'volatile_acidity : {mn_va}')
print(f'citric_acid : {mn_ca}')
print(f'residual_sugar : {mn_ra}')
print(f'chlorides : {mn_chl}')
print(f'free_sulphur_dioxide : {mn_fsd}')
print(f'total_sulfur_dioxide : {mn_tsd}')
print(f'density : {mn_dens}')
print(f'sulphates : {mn_sul}')
print(f'alcohol : {mn_alc}')
print(f'quality : {mn_qua}')
# Out:
# MEAN FOR THE VARIOUS COLUMNS
# fixed_acidity : 8.319875000000001
# volatile_acidity : 0.5277420362273579
# citric_acid : 0.271175
# residual_sugar : 2.5384447220487196
# chlorides : 0.0874874843554443
# free_sulphur_dioxide : 15.886875
# total_sulfur_dioxide : 46.52
# density : 0.9967456437500002
# sulphates : 0.6582198625858838
# alcohol : 10.42320424734541
# quality : 5.63625

# %% [markdown]
# MEDIAN FOR THE COLUMNS

# %%
md_fa=data.fixed_acidity.median()
md_va=data.volatile_acidity.median()
md_ca=data.citric_acid.median()
md_ra=data.residual_sugar.median()
md_chl=data.chlorides.median()
md_fsd=data.free_sulfur_dioxide.median()
md_tsd=data.total_sulfur_dioxide.median()
md_dens=data.density.median()
md_pH=data.pH.median()
md_sul=data.sulphates.median()
md_alc=data.alcohol.median()
md_qua=data.quality.median()

print('MEDIAN OF THE COLUMNS')
print(f'fixed_acidity : {md_fa}')
print(f'volatile_acidity : {md_va}')
print(f'citric_acid : {md_ca}')
print(f'residual_sugar : {md_ra}')
print(f'chlorides : {md_chl}')
print(f'free_sulphur_dioxide : {md_fsd}')
print(f'total_sulfur_dioxide : {md_tsd}')
print(f'density : {md_dens}')
print(f'pH : {md_pH}')
print(f'sulphates : {md_sul}')
print(f'alcohol : {md_alc}')
print(f'quality : {md_qua}')
# Out:
# MEDIAN OF THE COLUMNS
# fixed_acidity : 7.9
# volatile_acidity : 0.52
# citric_acid : 0.26
# residual_sugar : 2.2
# chlorides : 0.079
# free_sulphur_dioxide : 14.0
# total_sulfur_dioxide : 38.0
# density : 0.99675
# pH : 3.31
# sulphates : 0.62
# alcohol : 10.2
# quality : 6.0

# %% [markdown]
# MODE FOR THE COLUMNS

# %%
mo_fa=data.fixed_acidity.mode()
mo_va=data.volatile_acidity.mode()
mo_ca=data.citric_acid.mode()
mo_ra=data.residual_sugar.mode()
mo_chl=data.chlorides.mode()
mo_fsd=data.free_sulfur_dioxide.mode()
mo_tsd=data.total_sulfur_dioxide.mode()
mo_dens=data.density.mode()
mo_pH=data.pH.mode()
mo_sul=data.sulphates.mode()
mo_alc=data.alcohol.mode()
mo_qua=data.quality.mode()

print('MODE FOR THE COLUMNS')
print(f'fixed_acidity : {mo_fa}')
print(f'volatile_acidity : {mo_va}')
print(f'citric_acid : {mo_ca}')
print(f'residual_sugar : {mo_ra}')
print(f'chlorides : {mo_chl}')
print(f'free_sulphur_dioxide : {mo_fsd}')
print(f'total_sulfur_dioxide : {mo_tsd}')
print(f'density : {mo_dens}')
print(f'pH : {mo_pH}')
print(f'sulphates : {mo_sul}')
print(f'alcohol : {mo_alc}')
print(f'quality : {mo_qua}')
# Out:
# MODE FOR THE COLUMNS
# fixed_acidity : 0    7.2
# Name: fixed_acidity, dtype: float64
# volatile_acidity : 0    0.6
# Name: volatile_acidity, dtype: float64
# citric_acid : 0    0.0
# Name: citric_acid, dtype: float64
# residual_sugar : 0    2.0
# Name: residual_sugar, dtype: float64
# chlorides : 0    0.08
# Name: chlorides, dtype: float64
# free_sulphur_dioxide : 0    6.0
# Name: free_sulfur_dioxide, dtype: float64
# total_sulfur_dioxide : 0    28.0
# Name: total_sulfur_dioxide, dtype: float64
# density : 0    0.9972
# Name: density, dtype: float64
# pH : 0    3.3
# Name: pH, dtype: float64
# sulphates : 0    0.6
# Name: sulphates, dtype: float64
# alcohol : 0    9.5
# Name: alcohol, dtype: float64
# quality : 0    5.0
# Name: quality, dtype: float64

# %% [markdown]
# CORRELATION BETWEEN COLUMNS

# %%
correlation=data.corr()
data.corr()
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed_acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile_acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric_acid          -0.153294       0.670856         -0.552909     1.000000
# residual_sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free_sulfur_dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total_sulfur_dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# The mean values that were found were used to fill or replace all the null values in the dataframe method.This is more efficient and sustainable than the dropna method which tends to reduce the number of null values droped.

# %%
data['fixed_acidity']=data['fixed_acidity'].fillna(mn_fa)
data['citric_acid']=data['citric_acid'].fillna(mn_ca)
data['chlorides']=data['chlorides'].fillna(mn_chl)
data['free_sulfur_dioxide']=data['free_sulfur_dioxide'].fillna(mn_fsd)
data['total_sulfur_dioxide']=data['total_sulfur_dioxide'].fillna(mn_tsd)
data['density']=data['density'].fillna(mn_dens)
data['pH']=data['pH'].fillna(mn_pH)
data['quality']=data['quality'].fillna(mn_qua)

# %%
data.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# HEATMAP FOR THE DATA CORRELATION

# %% [markdown]
# The correlation matrix gives us the correlation between each pair of column in the dataset.A positive correlation coefficient indicates a positive correlation between the variables,while a neagative correlation coefficient indicates a negative relationship.A coefficient of 0 indicates no correlation.

# %%
 sns.heatmap(correlation, annot=True, fmt='0.1g')
# Out:
# <Axes: >

# %%
mpl.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
import ydata_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 import ydata_profiling
#
# ModuleNotFoundError: No module named 'ydata_profiling'
